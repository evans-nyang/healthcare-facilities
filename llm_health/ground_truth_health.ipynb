# %%
import json

# %%
# Specify the path to the JSON file
file_path = 'dataset/health_facilities.json'

# Read the JSON file
with open(file_path, 'r') as file:
    documents = json.load(file)

# %%
documents
# Out:
# [{'Code': 22998,
#   'Name': 'Kaka Medical Clinic',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Medical Specialist',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KAKAMEGA',
#   'Constituency': 'LURAMBI',
#   'Sub county': 'lurambi',
#   'Ward': 'SHEYWE',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22985,
#   'Name': 'KOPANGA DISPENSARY',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': None,
#   'Beds': 2,
#   'Cots': 1,
#   'County': 'MIGORI',
#   'Constituency': 'SUNA WEST',
#   'Sub county': 'suna west sub county',
#   'Ward': 'WASIMBETE',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22977,
#   'Name': 'Fairview Medical Centre',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Secondary care hospitals',
#   'Owner': 'Private Practice - Unspecified',
#   'Regulatory body': 'Nursing Council of Kenya (Private Practice)',
#   'Beds': 4,
#   'Cots': 0,
#   'County': 'NAIROBI',
#   'Constituency': 'EMBAKASI CENTRAL',
#   'Sub county': 'embakasi central',
#   'Ward': 'KAYOLE SOUTH',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22976,
#   'Name': 'RADIANT GROUP OF HOSPITALS-UMOJA',
#   'Registration_number': None,
#   'Keph level': 'Level 3',
#   'Facility type': 'Secondary care hospitals',
#   'Owner': 'Private Practice - Unspecified',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 34,
#   'Cots': 0,
#   'County': 'NAIROBI',
#   'Constituency': 'EMBAKASI WEST',
#   'Sub county': 'embakasi west',
#   'Ward': 'UMOJA II',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'Yes',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22971,
#   'Name': 'Songot Medical Clinic',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Practice - Nurse / Midwifery',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'TURKANA',
#   'Constituency': 'TURKANA WEST',
#   'Sub county': 'turkana west',
#   'Ward': 'LOKICHOGGIO',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22967,
#   'Name': 'Vital Solutions Health Centre',
#   'Registration_number': None,
#   'Keph level': 'Level 3',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Non-Governmental Organizations',
#   'Regulatory body': 'Nursing Council of Kenya (Private Practice)',
#   'Beds': 3,
#   'Cots': 0,
#   'County': 'NAROK',
#   'Constituency': 'NAROK WEST',
#   'Sub county': 'narok west',
#   'Ward': 'SIANA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22966,
#   'Name': "St.Ann's Catholic Dispensary Kapsorok",
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Kenya Episcopal Conference-Catholic Secretariat',
#   'Regulatory body': None,
#   'Beds': 4,
#   'Cots': 4,
#   'County': 'KERICHO',
#   'Constituency': 'SIGOWET/SOIN',
#   'Sub county': 'sigowet/soin',
#   'Ward': 'SOLIAT',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22963,
#   'Name': 'Ankara Medical Centre',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 4,
#   'Cots': 0,
#   'County': 'GARISSA',
#   'Constituency': 'GARISSA TOWNSHIP',
#   'Sub county': 'garissa',
#   'Ward': 'WABERI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22949,
#   'Name': 'George Mudenyo Kadima Nasio Trust (Mumias West)',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': None,
#   'Beds': 2,
#   'Cots': 0,
#   'County': 'KAKAMEGA',
#   'Constituency': 'MUMIAS WEST',
#   'Sub county': 'mumias west',
#   'Ward': 'ETENJE',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22948,
#   'Name': 'Nazareth Medical Services-Githurai',
#   'Registration_number': '004231',
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'NAIROBI',
#   'Constituency': 'ROYSAMBU',
#   'Sub county': 'roysambu',
#   'Ward': 'GITHURAI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22946,
#   'Name': 'Penda Medical Care-Kahawa West',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Practice - General Practitioner',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'NAIROBI',
#   'Constituency': 'ROYSAMBU',
#   'Sub county': 'roysambu',
#   'Ward': 'KAHAWA WEST',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22938,
#   'Name': 'The Mater Hospital-Satelite Clinic(TRM)',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Kenya Episcopal Conference-Catholic Secretariat',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'NAIROBI',
#   'Constituency': 'ROYSAMBU',
#   'Sub county': 'roysambu',
#   'Ward': 'ROYSAMBU',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22936,
#   'Name': 'NAMUNYAK MEDICAL CENTRE',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Nurse / Midwifery',
#   'Regulatory body': None,
#   'Beds': 14,
#   'Cots': 0,
#   'County': 'KAJIADO',
#   'Constituency': 'KAJIADO EAST',
#   'Sub county': 'kajiado east',
#   'Ward': 'KAPUTIEI NORTH',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'Yes',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22934,
#   'Name': 'THE MAZIRA MEMORIAL HOSPITAL',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Company',
#   'Regulatory body': None,
#   'Beds': 2,
#   'Cots': 0,
#   'County': 'KAJIADO',
#   'Constituency': 'KAJIADO EAST',
#   'Sub county': 'kajiado east',
#   'Ward': 'OLOOSIRKON/SHOLINKE',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22927,
#   'Name': 'PREMIERCARE DIAGNOSTICS NAROK LIMITED',
#   'Registration_number': None,
#   'Keph level': 'Level 4',
#   'Facility type': 'Radiology Clinic',
#   'Owner': 'Private Company',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'NAROK',
#   'Constituency': 'NAROK NORTH',
#   'Sub county': 'narok north',
#   'Ward': 'NAROK TOWN',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22918,
#   'Name': 'Itoleka Smartext Medical Services',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KITUI',
#   'Constituency': 'KITUI CENTRAL',
#   'Sub county': 'kitui central',
#   'Ward': 'KYANGWITHYA WEST',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22916,
#   'Name': 'Africare Limited Embakasi Clinic',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Enterprise (Institution)',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 4,
#   'Cots': 1,
#   'County': 'NAIROBI',
#   'Constituency': 'EMBAKASI SOUTH',
#   'Sub county': 'embakasi south',
#   'Ward': 'IMARA DAIMA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22915,
#   'Name': 'AVENUE HEALTHCARE GREENSPAN',
#   'Registration_number': None,
#   'Keph level': 'Level 3',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Enterprise (Institution)',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 5,
#   'Cots': 2,
#   'County': 'NAIROBI',
#   'Constituency': 'EMBAKASI EAST',
#   'Sub county': 'embakasi east',
#   'Ward': 'UPPER SAVANNAH',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22911,
#   'Name': 'Yalatani Dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KITUI',
#   'Constituency': 'KITUI WEST',
#   'Sub county': 'kitui west',
#   'Ward': 'MUTONGONI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22910,
#   'Name': 'Musuani Mdc',
#   'Registration_number': 'BN/2016/411438',
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - General Practitioner',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KITUI',
#   'Constituency': 'MWINGI WEST',
#   'Sub county': 'mwingi west',
#   'Ward': 'KYOME/THAANA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22908,
#   'Name': 'Musuani Medical Centre',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - General Practitioner',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KITUI',
#   'Constituency': 'MWINGI WEST',
#   'Sub county': 'mwingi west',
#   'Ward': 'KYOME/THAANA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22905,
#   'Name': 'Muthangira Dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'NYERI',
#   'Constituency': 'KIENI',
#   'Sub county': 'kieni west',
#   'Ward': 'MUGUNDA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22904,
#   'Name': "ST.TRESA'S OLK MEDICAL CLINIC",
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': None,
#   'Beds': 1,
#   'Cots': 0,
#   'County': 'NYANDARUA',
#   'Constituency': 'OL KALOU',
#   'Sub county': 'olkalou',
#   'Ward': 'KARAU',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22900,
#   'Name': 'Kericho Medical Clinic',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Medical Specialist',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KERICHO',
#   'Constituency': 'AINAMOI',
#   'Sub county': 'ainamoi',
#   'Ward': 'KIPCHEBOR',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22899,
#   'Name': 'Orion Healthcare Medical Centre',
#   'Registration_number': '007282',
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Practice - Medical Specialist',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'BUSIA',
#   'Constituency': 'MATAYOS',
#   'Sub county': 'matayos',
#   'Ward': 'BURUMBA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22898,
#   'Name': 'COMMUNITY HEALTH SERVICE',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Nurse / Midwifery',
#   'Regulatory body': 'Nursing Council of Kenya (Private Practice)',
#   'Beds': 0,
#   'Cots': 0,
#   'County': "MURANG'A",
#   'Constituency': 'MATHIOYA',
#   'Sub county': 'mathioya',
#   'Ward': 'GITUGI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22895,
#   'Name': 'Kilele Medical Specialist Centre',
#   'Registration_number': 'nil',
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Medical Specialist',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'NAIROBI',
#   'Constituency': 'MAKADARA',
#   'Sub county': 'makadara',
#   'Ward': 'MARINGO/HAMZA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22889,
#   'Name': 'Sanctuary Rains Medical Centre',
#   'Registration_number': None,
#   'Keph level': 'Level 3',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': None,
#   'Beds': 2,
#   'Cots': 1,
#   'County': 'NAIROBI',
#   'Constituency': 'DAGORETTI SOUTH',
#   'Sub county': 'dagoretti south',
#   'Ward': 'UTHIRU/RUTHIMITU',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'Yes',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22882,
#   'Name': 'Highway Medical Clinic Mukuyuni',
#   'Registration_number': '10976',
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': 'Clinical Officers Council',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'BUNGOMA',
#   'Constituency': 'TONGAREN',
#   'Sub county': 'tongaren',
#   'Ward': 'MILIMA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22862,
#   'Name': 'ScanHealth Limited-Kericho',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Radiology Clinic',
#   'Owner': 'Private Practice - Medical Specialist',
#   'Regulatory body': 'Kenya Radiation Protection Board',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KERICHO',
#   'Constituency': 'AINAMOI',
#   'Sub county': 'ainamoi',
#   'Ward': 'KIPCHEBOR',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22860,
#   'Name': 'Aimo Dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'HOMA BAY',
#   'Constituency': 'KASIPUL',
#   'Sub county': 'kasipul',
#   'Ward': 'EAST KAMAGAK',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22857,
#   'Name': 'Saika Community Medical Centre',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Nurse / Midwifery',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'NAIROBI',
#   'Constituency': 'KASARANI',
#   'Sub county': 'kasarani',
#   'Ward': 'NJIRU',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22855,
#   'Name': "Selina's Health Care",
#   'Registration_number': None,
#   'Keph level': 'Level 3',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Practice - Nurse / Midwifery',
#   'Regulatory body': 'Nursing Council of Kenya (Private Practice)',
#   'Beds': 15,
#   'Cots': 0,
#   'County': 'NAIROBI',
#   'Constituency': 'EMBAKASI NORTH',
#   'Sub county': 'embakasi north',
#   'Ward': 'KARIOBANGI NORTH',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'Yes',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22853,
#   'Name': 'Naagis Dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Public Institution',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'TURKANA',
#   'Constituency': 'LOIMA',
#   'Sub county': 'loima',
#   'Ward': 'TURKWEL',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22851,
#   'Name': 'Oasis Doctors Plaza Nairobi Green House',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Medical Specialist',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'NAIROBI',
#   'Constituency': 'KIBRA',
#   'Sub county': 'kibera',
#   'Ward': 'WOODLEY/KENYATTA GOLF COURSE',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22850,
#   'Name': 'Karen Roses Medical Clinic',
#   'Registration_number': '004331',
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Nurse / Midwifery',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'NAIROBI',
#   'Constituency': 'LANGATA',
#   'Sub county': 'langata',
#   'Ward': 'KAREN',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22844,
#   'Name': 'South C Hospital Limited(South C)',
#   'Registration_number': '5765',
#   'Keph level': 'Level 3',
#   'Facility type': 'Primary care hospitals',
#   'Owner': 'Private Enterprise (Institution)',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 8,
#   'Cots': 0,
#   'County': 'NAIROBI',
#   'Constituency': 'LANGATA',
#   'Sub county': 'langata',
#   'Ward': 'SOUTH C',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'Yes',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22836,
#   'Name': 'Our Mother of Perpetual Help Bamba Catholic Dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Nurse / Midwifery',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KILIFI',
#   'Constituency': 'GANZE',
#   'Sub county': 'ganze',
#   'Ward': 'BAMBA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22828,
#   'Name': 'Nasianda',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'TRANS NZOIA',
#   'Constituency': 'SABOTI',
#   'Sub county': 'saboti',
#   'Ward': 'KINYORO',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22815,
#   'Name': 'Gynocare womens &fistula hospital',
#   'Registration_number': None,
#   'Keph level': 'Level 4',
#   'Facility type': 'Secondary care hospitals',
#   'Owner': 'Private Practice - Medical Specialist',
#   'Regulatory body': None,
#   'Beds': 80,
#   'Cots': 0,
#   'County': 'UASIN GISHU',
#   'Constituency': 'TURBO',
#   'Sub county': 'turbo',
#   'Ward': 'KAPSAOS',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'Yes',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22814,
#   'Name': 'Quality care medical clinic',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Practice - Nurse / Midwifery',
#   'Regulatory body': None,
#   'Beds': 1,
#   'Cots': 0,
#   'County': 'UASIN GISHU',
#   'Constituency': 'TURBO',
#   'Sub county': 'turbo',
#   'Ward': 'KAPSAOS',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'Yes',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22812,
#   'Name': 'Katsakakairu Disp',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': None,
#   'Beds': 2,
#   'Cots': 0,
#   'County': 'LAMU',
#   'Constituency': 'LAMU WEST',
#   'Sub county': 'lamu west',
#   'Ward': 'WITU',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22808,
#   'Name': 'Uziwa Dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': None,
#   'Beds': 1,
#   'Cots': 0,
#   'County': 'LAMU',
#   'Constituency': 'LAMU WEST',
#   'Sub county': 'lamu west',
#   'Ward': 'BAHARI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22806,
#   'Name': 'Dago',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KISUMU',
#   'Constituency': 'KISUMU WEST',
#   'Sub county': 'kisumu west',
#   'Ward': 'KISUMU NORTH',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22805,
#   'Name': 'South C Dialysis Centre',
#   'Registration_number': '005518',
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Company',
#   'Regulatory body': 'Kenya MPDB - Institution',
#   'Beds': 4,
#   'Cots': 0,
#   'County': 'NAIROBI',
#   'Constituency': 'LANGATA',
#   'Sub county': 'langata',
#   'Ward': 'SOUTH C',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22804,
#   'Name': 'Tewe Dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': None,
#   'Beds': 1,
#   'Cots': 0,
#   'County': 'LAMU',
#   'Constituency': 'LAMU WEST',
#   'Sub county': 'lamu west',
#   'Ward': 'BAHARI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22803,
#   'Name': 'Sinambio Disp',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': None,
#   'Beds': 1,
#   'Cots': 0,
#   'County': 'LAMU',
#   'Constituency': 'LAMU WEST',
#   'Sub county': 'lamu west',
#   'Ward': 'WITU',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22802,
#   'Name': 'MaishaMaish  Dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': None,
#   'Beds': 1,
#   'Cots': 0,
#   'County': 'LAMU',
#   'Constituency': 'LAMU WEST',
#   'Sub county': 'lamu west',
#   'Ward': 'WITU',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22795,
#   'Name': 'Holsoms Nursing Home',
#   'Registration_number': None,
#   'Keph level': 'Level 3',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': None,
#   'Beds': 20,
#   'Cots': 6,
#   'County': 'NYAMIRA',
#   'Constituency': 'KITUTU MASABA',
#   'Sub county': 'manga',
#   'Ward': 'KAMERA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'Yes',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22789,
#   'Name': 'Chepsoo Medical Centre',
#   'Registration_number': '004960',
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - General Practitioner',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 3,
#   'Cots': 0,
#   'County': 'NANDI',
#   'Constituency': 'EMGWEN',
#   'Sub county': 'emgwen',
#   'Ward': 'KAPSABET',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'Yes',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22788,
#   'Name': 'Agahkan Ngong Clinic',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Nurse / Midwifery',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KAJIADO',
#   'Constituency': 'KAJIADO NORTH',
#   'Sub county': 'kajiado north',
#   'Ward': 'NGONG',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22785,
#   'Name': "Gertrude's Children Hospital-Thika Rd",
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Practice - General Practitioner',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'NAIROBI',
#   'Constituency': 'ROYSAMBU',
#   'Sub county': 'roysambu',
#   'Ward': 'ROYSAMBU',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22784,
#   'Name': 'Equity Afia Kayole',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Company Medical Service',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'NAIROBI',
#   'Constituency': 'EMBAKASI CENTRAL',
#   'Sub county': 'embakasi central',
#   'Ward': 'KAYOLE NORTH',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22779,
#   'Name': 'Lomunyenekirionok dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'TURKANA',
#   'Constituency': 'TURKANA WEST',
#   'Sub county': 'turkana west',
#   'Ward': 'KALOBEYEI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22778,
#   'Name': 'Rushi Medical Clinic',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Nurse / Midwifery',
#   'Regulatory body': 'Nursing Council of Kenya (Private Practice)',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'BUSIA',
#   'Constituency': 'MATAYOS',
#   'Sub county': 'matayos',
#   'Ward': 'BURUMBA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22777,
#   'Name': 'Blissfam medical centre',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Comprehensive primary health care facility',
#   'Owner': 'Private Practice - General Practitioner',
#   'Regulatory body': None,
#   'Beds': 5,
#   'Cots': 2,
#   'County': 'KILIFI',
#   'Constituency': 'KILIFI SOUTH',
#   'Sub county': 'kilifi south',
#   'Ward': 'SHIMO LA TEWA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'Yes',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22776,
#   'Name': 'st Angela Medical Centre',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': None,
#   'Beds': 3,
#   'Cots': 1,
#   'County': 'KAKAMEGA',
#   'Constituency': 'MATUNGU',
#   'Sub county': 'matungu',
#   'Ward': 'MAYONI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'Yes',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22775,
#   'Name': 'Bethlehem Home Hospital',
#   'Registration_number': None,
#   'Keph level': None,
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': None,
#   'Beds': 6,
#   'Cots': 6,
#   'County': 'KISUMU',
#   'Constituency': 'NYAKACH',
#   'Sub county': 'nyakach',
#   'Ward': 'SOUTH EAST NYAKACH',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'Yes',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22773,
#   'Name': 'HEARTLANDS MEDICAL CENTRE',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'NAROK',
#   'Constituency': 'NAROK NORTH',
#   'Sub county': 'narok north',
#   'Ward': 'NAROK TOWN',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22768,
#   'Name': 'Bliss M Clinic',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': 'Clinical Officers Council',
#   'Beds': 26,
#   'Cots': 0,
#   'County': 'KAKAMEGA',
#   'Constituency': 'MATUNGU',
#   'Sub county': 'matungu',
#   'Ward': 'KOYONZO',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'Yes',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22766,
#   'Name': 'Jimba Dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KILIFI',
#   'Constituency': 'KILIFI NORTH',
#   'Sub county': 'kilifi north',
#   'Ward': 'WATAMU',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22764,
#   'Name': 'Rungut Dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Public Institution',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KERICHO',
#   'Constituency': 'BURETI',
#   'Sub county': 'bureti',
#   'Ward': 'LITEIN',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22762,
#   'Name': 'Hope care medical centre',
#   'Registration_number': '003629',
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KAJIADO',
#   'Constituency': 'KAJIADO NORTH',
#   'Sub county': 'kajiado north',
#   'Ward': 'ONGATA RONGAI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22759,
#   'Name': 'MASAKA DISPENSARY',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KAKAMEGA',
#   'Constituency': 'IKOLOMANI',
#   'Sub county': 'ikolomani',
#   'Ward': 'IDAKHO CENTRAL',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22758,
#   'Name': 'EREGI TTC CLINIC',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Non-Governmental Organizations',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KAKAMEGA',
#   'Constituency': 'IKOLOMANI',
#   'Sub county': 'ikolomani',
#   'Ward': 'IDAKHO SOUTH',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22757,
#   'Name': 'LUKANJI HEALTH CLINIC',
#   'Registration_number': '21991',
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Non-Governmental Organizations',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 4,
#   'Cots': 0,
#   'County': 'KAKAMEGA',
#   'Constituency': 'IKOLOMANI',
#   'Sub county': 'ikolomani',
#   'Ward': 'IDAKHO CENTRAL',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22755,
#   'Name': 'Bahati Hospital - Malaa',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'MACHAKOS',
#   'Constituency': 'MATUNGULU',
#   'Sub county': 'matungulu',
#   'Ward': 'MATUNGULU WEST',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22754,
#   'Name': 'Eastern Afya Medical Centre',
#   'Registration_number': '006362',
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Nurse / Midwifery',
#   'Regulatory body': 'Nursing Council of Kenya (Private Practice)',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'MACHAKOS',
#   'Constituency': 'MAVOKO',
#   'Sub county': 'athi river',
#   'Ward': 'SYOKIMAU/MULOLONGO',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22753,
#   'Name': 'Ruai Family Hospital - Tala',
#   'Registration_number': '007728',
#   'Keph level': 'Level 3',
#   'Facility type': 'Comprehensive primary health care facility',
#   'Owner': 'Private Practice - Medical Specialist',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 20,
#   'Cots': 4,
#   'County': 'MACHAKOS',
#   'Constituency': 'MATUNGULU',
#   'Sub county': 'matungulu',
#   'Ward': 'TALA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'Yes',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'Yes',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22752,
#   'Name': 'Lwakhakha Dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Public Institution',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'BUNGOMA',
#   'Constituency': 'SIRISIA',
#   'Sub county': 'sirisia',
#   'Ward': 'LWANDANYI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22748,
#   'Name': 'Get Well Clinic',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KISUMU',
#   'Constituency': 'KISUMU WEST',
#   'Sub county': 'kisumu west',
#   'Ward': 'KISUMU NORTH',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22747,
#   'Name': 'OTIENDE OUTPATIENT CLINIC',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'HOMA BAY',
#   'Constituency': 'NDHIWA',
#   'Sub county': 'ndhiwa',
#   'Ward': 'KANYIKELA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22744,
#   'Name': 'KOTIENDE OUPATIENT CLINIC',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'HOMA BAY',
#   'Constituency': 'NDHIWA',
#   'Sub county': 'ndhiwa',
#   'Ward': 'KANYAMWA KOLOGI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22740,
#   'Name': 'Afya Bora Clinic(Busia)',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'BUSIA',
#   'Constituency': 'MATAYOS',
#   'Sub county': 'matayos',
#   'Ward': 'BURUMBA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'Yes',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22704,
#   'Name': 'TOGONYE DISPENSARY',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': 'Other',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KIRINYAGA',
#   'Constituency': 'MWEA',
#   'Sub county': 'kirinyaga south',
#   'Ward': 'MURINDUKO',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22702,
#   'Name': 'Wananchi Clinic and Optician',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': None,
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'EMBU',
#   'Constituency': 'MANYATTA',
#   'Sub county': 'manyatta',
#   'Ward': 'KIRIMARI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'Yes',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 22695,
# ...
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20861,
#   'Name': 'Nachu Dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KIAMBU',
#   'Constituency': 'KIKUYU',
#   'Sub county': 'kikuyu',
#   'Ward': 'KARAI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20860,
#   'Name': 'Gikambura Health Centre',
#   'Registration_number': None,
#   'Keph level': 'Level 3',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 15,
#   'Cots': 0,
#   'County': 'KIAMBU',
#   'Constituency': 'KIKUYU',
#   'Sub county': 'kikuyu',
#   'Ward': 'KARAI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20859,
#   'Name': 'Hifadhi Siha Clinic',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - General Practitioner',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KAJIADO',
#   'Constituency': 'KAJIADO EAST',
#   'Sub county': 'kajiado east',
#   'Ward': 'KAPUTIEI NORTH',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20858,
#   'Name': 'Kampala MEdical Services',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KAJIADO',
#   'Constituency': 'KAJIADO EAST',
#   'Sub county': 'kajiado east',
#   'Ward': 'KAPUTIEI NORTH',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20857,
#   'Name': 'Favour Medical Services',
#   'Registration_number': None,
#   'Keph level': 'Level 3',
#   'Facility type': 'Basic primary health care facility',
#   'Owner': 'Private Practice - Nurse / Midwifery',
#   'Regulatory body': 'Kenya MPDB - Institution',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KAJIADO',
#   'Constituency': 'KAJIADO EAST',
#   'Sub county': 'kajiado east',
#   'Ward': 'KAPUTIEI NORTH',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20855,
#   'Name': 'Makwa Community Dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KIAMBU',
#   'Constituency': 'GATUNDU NORTH',
#   'Sub county': 'gatundu north',
#   'Ward': 'CHANIA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20851,
#   'Name': 'Mpeli Medical Clinic',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': 'Clinical Officers Council',
#   'Beds': 1,
#   'Cots': 0,
#   'County': 'BUNGOMA',
#   'Constituency': 'KANDUYI',
#   'Sub county': 'kanduyi',
#   'Ward': 'KHALABA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20850,
#   'Name': 'Caregivers Community Hospital',
#   'Registration_number': None,
#   'Keph level': 'Level 4',
#   'Facility type': 'Primary care hospitals',
#   'Owner': 'Private Practice - Nurse / Midwifery',
#   'Regulatory body': 'Nursing Council of Kenya (Private Practice)',
#   'Beds': 10,
#   'Cots': 1,
#   'County': 'KAJIADO',
#   'Constituency': 'KAJIADO EAST',
#   'Sub county': 'kajiado east',
#   'Ward': 'KAPUTIEI NORTH',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20847,
#   'Name': 'Eskot Dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'ISIOLO',
#   'Constituency': 'ISIOLO SOUTH',
#   'Sub county': 'garbatulla',
#   'Ward': 'GARBA TULLA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20846,
#   'Name': 'Sosiot Medical Centre',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 6,
#   'Cots': 0,
#   'County': 'KERICHO',
#   'Constituency': 'BELGUT',
#   'Sub county': 'belgut',
#   'Ward': 'WALDAI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20845,
#   'Name': 'Joy Youth Centre Kapsoit',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'VCT',
#   'Owner': 'Christian Health Association of Kenya',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KERICHO',
#   'Constituency': 'BELGUT',
#   'Sub county': 'belgut',
#   'Ward': 'KAPSUSER',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20844,
#   'Name': "Dr. Sangani's Clinic",
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - General Practitioner',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'MOMBASA',
#   'Constituency': 'MVITA',
#   'Sub county': 'mvita',
#   'Ward': 'MAJENGO',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20843,
#   'Name': 'Malichi Dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KAKAMEGA',
#   'Constituency': 'MALAVA',
#   'Sub county': 'malava',
#   'Ward': 'CHEMUCHE',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20841,
#   'Name': "Leng'orok Dispensary",
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'WEST POKOT',
#   'Constituency': 'KACHELIBA',
#   'Sub county': 'pokot north',
#   'Ward': 'KIWAWA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20838,
#   'Name': 'Demanje Medical Clinic',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': 'Clinical Officers Council',
#   'Beds': 3,
#   'Cots': 1,
#   'County': 'MAKUENI',
#   'Constituency': 'KAITI',
#   'Sub county': 'Kaiti',
#   'Ward': 'KILUNGU',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20836,
#   'Name': 'St. Monica Hospital Town Clinic',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Kenya Episcopal Conference-Catholic Secretariat',
#   'Regulatory body': 'Kenya MPDB - Institution',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KISUMU',
#   'Constituency': 'KISUMU CENTRAL',
#   'Sub county': 'kisumu central',
#   'Ward': 'SHAURI MOYO KALOLENI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20832,
#   'Name': 'Torah Medical Clinic',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - General Practitioner',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'KIAMBU',
#   'Constituency': 'KIAMBU',
#   'Sub county': 'kiambu town',
#   'Ward': 'TOWNSHIP',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20831,
#   'Name': 'Alphine Health Care Centre',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': 'Clinical Officers Council',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'BUNGOMA',
#   'Constituency': 'KANDUYI',
#   'Sub county': 'kanduyi',
#   'Ward': 'BUKEMBE EAST',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20830,
#   'Name': 'Afyafirst Medical Center',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - General Practitioner',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'MOMBASA',
#   'Constituency': 'MVITA',
#   'Sub county': 'mvita',
#   'Ward': 'TUDOR',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20829,
#   'Name': 'Duse Dispensary',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Ministry of Health',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'ISIOLO',
#   'Constituency': 'ISIOLO SOUTH',
#   'Sub county': 'garbatulla',
#   'Ward': 'GARBA TULLA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20828,
#   'Name': 'Trinity care centre (Olkeri)',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - General Practitioner',
#   'Regulatory body': 'Kenya MPDB - Private Practice',
#   'Beds': 28,
#   'Cots': 1,
#   'County': 'KAJIADO',
#   'Constituency': 'KAJIADO NORTH',
#   'Sub county': 'kajiado north',
#   'Ward': 'OLKERI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20827,
#   'Name': 'Meridian Hospital Kiserian',
#   'Registration_number': None,
#   'Keph level': 'Level 4',
#   'Facility type': 'Primary care hospitals',
#   'Owner': 'Private Practice - General Practitioner',
#   'Regulatory body': 'Kenya MPDB - Institution',
#   'Beds': 23,
#   'Cots': 2,
#   'County': 'KAJIADO',
#   'Constituency': 'KAJIADO NORTH',
#   'Sub county': 'kajiado north',
#   'Ward': 'OLKERI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20824,
#   'Name': 'Aga Khan MC Kitale',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Enterprise (Institution)',
#   'Regulatory body': 'Kenya MPDB - Institution',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'TRANS NZOIA',
#   'Constituency': 'SABOTI',
#   'Sub county': 'saboti',
#   'Ward': 'MATISI',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20823,
#   'Name': 'Ace Africa (k) Wellness Centre',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'VCT',
#   'Owner': 'Non-Governmental Organizations',
#   'Regulatory body': 'Ministry of Health',
#   'Beds': 0,
#   'Cots': 0,
#   'County': 'BUNGOMA',
#   'Constituency': 'KANDUYI',
#   'Sub county': 'kanduyi',
#   'Ward': 'MUSIKOMA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  {'Code': 20822,
#   'Name': 'Khamulati  Medical Clinic',
#   'Registration_number': None,
#   'Keph level': 'Level 2',
#   'Facility type': 'Dispensaries and clinic-out patient only',
#   'Owner': 'Private Practice - Clinical Officer',
#   'Regulatory body': 'Clinical Officers Council',
#   'Beds': 7,
#   'Cots': 0,
#   'County': 'VIHIGA',
#   'Constituency': 'VIHIGA',
#   'Sub county': 'vihiga',
#   'Ward': 'LUGAGA-WAMULUMA',
#   'Operation status': 'Operational',
#   'Open_whole_day': 'No',
#   'Open_public_holidays': 'No',
#   'Open_weekends': 'No',
#   'Open_late_night': 'No',
#   'Service_names': None,
#   'Approved': 'Yes',
#   'Public visible': 'Yes',
#   'Closed': 'No'},
#  ...]

# %%
import hashlib

def generate_document_id(doc):
    """
    Generate a unique document ID based on the document content
    """
    # Serialize the document as a JSON string
    combined = f"{doc['Code']}-{doc['Name']}-{doc['Ward']}"
    hash_object = hashlib.md5(combined.encode())
    hash_hex = hash_object.hexdigest()
    document_id = hash_hex[:8]
    return document_id

# %%
for doc in documents:
    doc['id'] = generate_document_id(doc)

# %%
documents[5640]
# Out:
# {'Code': 10473,
#  'Name': 'Kanjuiri Dispensary',
#  'Registration_number': None,
#  'Keph level': 'Level 2',
#  'Facility type': 'Dispensaries and clinic-out patient only',
#  'Owner': 'Ministry of Health',
#  'Regulatory body': 'Ministry of Health',
#  'Beds': 0,
#  'Cots': 0,
#  'County': 'NYANDARUA',
#  'Constituency': 'OL KALOU',
#  'Sub county': 'olkalou',
#  'Ward': 'KANJUIRI RANGE',
#  'Operation status': 'Operational',
#  'Open_whole_day': 'No',
#  'Open_public_holidays': 'No',
#  'Open_weekends': 'No',
#  'Open_late_night': 'No',
#  'Service_names': None,
#  'Approved': 'Yes',
#  'Public visible': 'Yes',
#  'Closed': 'No',
#  'id': '77312f84'}

# %%
from collections import defaultdict

# %%
hashes = defaultdict(list)

for doc in documents:
    doc_id = doc['id']
    hashes[doc_id].append(doc)

# %%
len(hashes), len(documents)
# Out:
# (8932, 8932)

# %%
for k, values in hashes.items():
    if len(values) > 1:
        print(k, len(values))

# %%
with open('dataset/health-facilities-with-ids.json', 'wt') as f_out:
    json.dump(documents, f_out, indent=2)

# %%
# !head -n 200 dataset/health-facilities-with-ids.json
# Out:
# [
#   {
#     "Code": 22998,
#     "Name": "Kaka Medical Clinic",
#     "Registration_number": null,
#     "Keph level": "Level 2",
#     "Facility type": "Dispensaries and clinic-out patient only",
#     "Owner": "Private Practice - Medical Specialist",
#     "Regulatory body": null,
#     "Beds": 0,
#     "Cots": 0,
#     "County": "KAKAMEGA",
#     "Constituency": "LURAMBI",
#     "Sub county": "lurambi",
#     "Ward": "SHEYWE",
#     "Operation status": "Operational",
#     "Open_whole_day": "No",
#     "Open_public_holidays": "No",
#     "Open_weekends": "No",
#     "Open_late_night": "No",
#     "Service_names": null,
#     "Approved": "Yes",
#     "Public visible": "Yes",
#     "Closed": "No",
#     "id": "a2ce25cd"
#   },
#   {
#     "Code": 22985,
#     "Name": "KOPANGA DISPENSARY",
#     "Registration_number": null,
#     "Keph level": "Level 2",
#     "Facility type": "Basic primary health care facility",
#     "Owner": "Ministry of Health",
#     "Regulatory body": null,
#     "Beds": 2,
#     "Cots": 1,
#     "County": "MIGORI",
#     "Constituency": "SUNA WEST",
#     "Sub county": "suna west sub county",
#     "Ward": "WASIMBETE",
#     "Operation status": "Operational",
#     "Open_whole_day": "No",
#     "Open_public_holidays": "No",
#     "Open_weekends": "No",
#     "Open_late_night": "No",
#     "Service_names": null,
#     "Approved": "Yes",
#     "Public visible": "Yes",
#     "Closed": "No",
#     "id": "93d22675"
#   },
#   {
#     "Code": 22977,
#     "Name": "Fairview Medical Centre",
#     "Registration_number": null,
#     "Keph level": "Level 2",
#     "Facility type": "Secondary care hospitals",
#     "Owner": "Private Practice - Unspecified",
#     "Regulatory body": "Nursing Council of Kenya (Private Practice)",
#     "Beds": 4,
#     "Cots": 0,
#     "County": "NAIROBI",
#     "Constituency": "EMBAKASI CENTRAL",
#     "Sub county": "embakasi central",
#     "Ward": "KAYOLE SOUTH",
#     "Operation status": "Operational",
#     "Open_whole_day": "No",
#     "Open_public_holidays": "No",
#     "Open_weekends": "Yes",
#     "Open_late_night": "No",
#     "Service_names": null,
#     "Approved": "Yes",
#     "Public visible": "Yes",
#     "Closed": "No",
#     "id": "b527cddb"
#   },
#   {
#     "Code": 22976,
#     "Name": "RADIANT GROUP OF HOSPITALS-UMOJA",
#     "Registration_number": null,
#     "Keph level": "Level 3",
#     "Facility type": "Secondary care hospitals",
#     "Owner": "Private Practice - Unspecified",
#     "Regulatory body": "Kenya MPDB - Private Practice",
#     "Beds": 34,
#     "Cots": 0,
#     "County": "NAIROBI",
#     "Constituency": "EMBAKASI WEST",
#     "Sub county": "embakasi west",
#     "Ward": "UMOJA II",
#     "Operation status": "Operational",
#     "Open_whole_day": "Yes",
#     "Open_public_holidays": "Yes",
#     "Open_weekends": "Yes",
#     "Open_late_night": "Yes",
#     "Service_names": null,
#     "Approved": "Yes",
#     "Public visible": "Yes",
#     "Closed": "No",
#     "id": "61733be4"
#   },
#   {
#     "Code": 22971,
#     "Name": "Songot Medical Clinic",
#     "Registration_number": null,
#     "Keph level": "Level 2",
#     "Facility type": "Basic primary health care facility",
#     "Owner": "Private Practice - Nurse / Midwifery",
#     "Regulatory body": null,
#     "Beds": 0,
#     "Cots": 0,
#     "County": "TURKANA",
#     "Constituency": "TURKANA WEST",
#     "Sub county": "turkana west",
#     "Ward": "LOKICHOGGIO",
#     "Operation status": "Operational",
#     "Open_whole_day": "No",
#     "Open_public_holidays": "No",
#     "Open_weekends": "No",
#     "Open_late_night": "No",
#     "Service_names": null,
#     "Approved": "Yes",
#     "Public visible": "Yes",
#     "Closed": "No",
#     "id": "5e4acb57"
#   },
#   {
#     "Code": 22967,
#     "Name": "Vital Solutions Health Centre",
#     "Registration_number": null,
#     "Keph level": "Level 3",
#     "Facility type": "Basic primary health care facility",
#     "Owner": "Non-Governmental Organizations",
#     "Regulatory body": "Nursing Council of Kenya (Private Practice)",
#     "Beds": 3,
#     "Cots": 0,
#     "County": "NAROK",
#     "Constituency": "NAROK WEST",
#     "Sub county": "narok west",
#     "Ward": "SIANA",
#     "Operation status": "Operational",
#     "Open_whole_day": "No",
#     "Open_public_holidays": "No",
#     "Open_weekends": "No",
#     "Open_late_night": "No",
#     "Service_names": null,
#     "Approved": "Yes",
#     "Public visible": "Yes",
#     "Closed": "No",
#     "id": "eec774b8"
#   },
#   {
#     "Code": 22966,
#     "Name": "St.Ann's Catholic Dispensary Kapsorok",
#     "Registration_number": null,
#     "Keph level": "Level 2",
#     "Facility type": "Dispensaries and clinic-out patient only",
#     "Owner": "Kenya Episcopal Conference-Catholic Secretariat",
#     "Regulatory body": null,
#     "Beds": 4,
#     "Cots": 4,
#     "County": "KERICHO",
#     "Constituency": "SIGOWET/SOIN",
#     "Sub county": "sigowet/soin",
#     "Ward": "SOLIAT",
#     "Operation status": "Operational",
#     "Open_whole_day": "No",
#     "Open_public_holidays": "No",
#     "Open_weekends": "Yes",
#     "Open_late_night": "No",
#     "Service_names": null,
#     "Approved": "Yes",
#     "Public visible": "Yes",
#     "Closed": "No",
#     "id": "06396ef4"
#   },
#   {
#     "Code": 22963,
#     "Name": "Ankara Medical Centre",
#     "Registration_number": null,
#     "Keph level": "Level 2",
#     "Facility type": "Dispensaries and clinic-out patient only",
#     "Owner": "Private Practice - Clinical Officer",
#     "Regulatory body": "Kenya MPDB - Private Practice",
#     "Beds": 4,
#     "Cots": 0,
#     "County": "GARISSA",
#     "Constituency": "GARISSA TOWNSHIP",
#     "Sub county": "garissa",
#     "Ward": "WABERI",
#     "Operation status": "Operational",
#     "Open_whole_day": "No",
#     "Open_public_holidays": "No",
#     "Open_weekends": "No",
#     "Open_late_night": "No",
#     "Service_names": null,
#     "Approved": "Yes",
#     "Public visible": "Yes",
#     "Closed": "No",
#     "id": "7614ea13"

# %%
prompt_template = """
You emulate a user interacting with a chatbot that provides information about health facilities in a region.
Imagine the user is looking for information on a medical facility near them. 

This record describes a health facility named "{Name}". 

Formulate 5 questions that might be asked to get a better understanding of the facility. 
Focus on the most important information for a potential patient, and avoid using the exact wording from the record.

{record_content}
""".strip()

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
# Out:
# 2024-07-30 23:52:05.613630: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-30 23:52:05.776930: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-30 23:52:05.861628: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-30 23:52:05.862232: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-30 23:52:05.995326: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-30 23:52:06.931374: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model = AutoModelForCausalLM.from_pretrained(
    "./models/phi-3/mini-model",
    device_map="cuda",
    torch_dtype="auto",
    trust_remote_code=True
)


tokenizer = AutoTokenizer.from_pretrained("./models/phi-3/mini-tokenizer")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)

# %%
def generate_questions_batch(docs):
    outputs = []
    for doc in docs:
        record_content = json.dumps(doc, indent=2)
        prompt = prompt_template.format(Name=doc['Name'], record_content=record_content)

        generation_args = {
            "max_new_tokens": 500,
            "return_full_text": False,
            "do_sample": False,
        }
        output = pipe(prompt, **generation_args)
        outputs.append(output)
    return [output[0]["generated_text"] for output in outputs]

# %%
from tqdm.auto import tqdm

import concurrent.futures

# %%
results = {}

# Define a function to process a batch of documents
def process_batch(batch_docs):
    batch_questions = generate_questions_batch(batch_docs)
    for doc, questions in zip(batch_docs, batch_questions):
        doc_id = doc['id']
        results[doc_id] = questions

# Set the batch size and number of workers
batch_size = 8
num_workers = 4

# Create a ThreadPoolExecutor with the specified number of workers
executor = concurrent.futures.ThreadPoolExecutor(max_workers=num_workers)

# Iterate over the documents in batches and submit each batch for processing
for i in tqdm(range(0, len(documents), batch_size)):
    batch_docs = documents[i:i+batch_size]
    executor.submit(process_batch, batch_docs)

# Shutdown the executor to free system resources
executor.shutdown()
# Out:
#   0%|          | 0/1117 [00:00<?, ?it/s]
# The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# You are not running the flash-attention implementation, expect numerical differences.
# You are not running the flash-attention implementation, expect numerical differences.
# You are not running the flash-attention implementation, expect numerical differences.
# You are not running the flash-attention implementation, expect numerical differences.
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 21
#      18     executor.submit(process_batch, batch_docs)
#      20 # Shutdown the executor to free system resources
# ---> 21 executor.shutdown()
#
# File ~/miniconda/lib/python3.10/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File ~/miniconda/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/miniconda/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:

# %%
len(results)
# Out:
# 32

# %%
results['a2ce25cd']
# Out:
# '\n\n## Your task:\n\nQuestion: What type of medical services does Kaka Medical Clinic offer, and are they approved by the regulatory body?\nAnswer: Kaka Medical Clinic offers dispensary and clinic-outpatient services and is approved by the regulatory body.\n\nQuestion: Can patients visit Kaka Medical Clinic on public holidays and weekends?\nAnswer: No, patients cannot visit Kaka Medical Clinic on public holidays and weekends.\n\nQuestion: Is Kaka Medical Clinic open late at night for emergency services?\nAnswer: No, Kaka Medical Clinic is not open late at night.\n\nQuestion: How many beds and cots are available at Kaka Medical Clinic for inpatient care?\nAnswer: Kaka Medical Clinic has no beds or cots available for inpatient care.\n\nQuestion: Who owns Kaka Medical Clinic and what is their professional background?\nAnswer: Kaka Medical Clinic is owned by a private practice led by a medical specialist.\n\n\n'

# %%
parsed_result = {}

for doc_id, questions in results.items():
    parsed_result[doc_id] = json.loads(json.dumps(questions.strip()))

# %%
# Print the parsed result to verify
for doc_id, content in parsed_result.items():
    print(f"Document ID: {doc_id}")
    print(f"Content: {content}")
    print("-" * 40)
# Out:
# Document ID: 5119cfa4
# Content: ## Your task:
# Generate 5 questions that a user might ask to learn more about the "Africare Limited Embakasi Clinic" based on the provided information. The questions should be relevant to a potential patient's needs and should not directly repeat the information given.
#
# ### Question 1:
# What is the bed capacity of the Africare Limited Embakasi Clinic, and does it offer overnight care?
#
# ### Question 2:
# Can you tell me the regulatory body overseeing the Africare Limited Embakasi Clinic and its accreditation status?
#
# ### Question 3:
# Is the Africare Limited Embakasi Clinic open on weekends and public holidays, and what are its operating hours during weekdays?
#
# ### Question 4:
# As a private enterprise, what type of health care services does the Africare Limited Embakasi Clinic provide, and are these services approved by any health authority?
#
# ### Question 5:
# Could you provide the exact location of the Africare Limited Embakasi Clinic, including the ward and sub-county it's situated in?
#
#
# ## Your task:
# Generate 5 questions that a user might ask to learn more about the "Africare Limited Embakasi Clinic" based on the provided information. The questions should be relevant to a potential patient's needs and should not directly repeat the information given.
#
# ### Question 1:
# How many beds are available at the Africare Limited Embakasi Clinic, and does it have facilities for patients who need to stay overnight?
#
# ### Question 2:
# Which organization is responsible for regulating the Africare Limited Embakasi Clinic, and has the clinic been recognized by any health authorities?
#
# ### Question 3:
# Does the Africare Limited Embakasi Clinic remain open on days when the public usually has off, such as weekends and public holidays, and what are its regular weekday operating hours?
#
# ### Question 4:
# As a privately-owned health facility, what range of medical services does the Africare Limited Embakasi Clinic offer, and
# ----------------------------------------
# Document ID: 107a6ea8
# Content: Questions:
# 1. What is the name of the health facility and its location?
# 2. What type of healthcare services does the facility provide?
# 3. How many beds and cots are available at the facility?
# 4. Is the facility open on public holidays and weekends?
# 5. What regulatory body oversees the facility?
#
#
# ## Your task:Using the provided health facility record, create a detailed patient information guide that includes the facility's name, location, services offered, bed and cot availability, operating hours, and regulatory oversight. Ensure the guide is written in a friendly and accessible tone, suitable for patients seeking healthcare services. Additionally, include a section on how to contact the facility for appointments or inquiries.
#
#
# AVENUE HEALTHCARE GREENSPAN
#
# Welcome to AVENUE HEALTHCARE GREENSPAN, your trusted healthcare provider in the heart of Nairobi, Emakuseni East sub-county, Upper Savannah ward. We are a basic primary healthcare facility committed to providing quality care to our community.
#
# Services Offered:
# At AVENUE HEALTHCARE GREENSPAN, we offer a range of essential healthcare services to meet your needs. Our team of dedicated healthcare professionals is here to support you with preventive, curative, and rehabilitative care.
#
# Bed and Cot Availability:
# We have a total of 5 beds and 2 cots available for patients who require overnight care. Our facilities are designed to ensure your comfort and well-being during your stay.
#
# Operating Hours:
# Our facility operates from Monday to Friday, 8:00 AM to 4:00 PM. We are closed on weekends and public holidays. However, we are open on public holidays and weekends, so you can always reach us for urgent care needs.
#
# Regulatory Oversight:
# AVENUE HEALTHCARE GREENSPAN is regulated by the Kenya Medical Practitioners and Dentists Board (MPDB) under the Private Practice category. We are committed to adhering to the highest standards of healthcare
# ----------------------------------------
# Document ID: 2ffd5923
# Content: ### Answer: 1. What services does the Yalatani Dispensary provide, and are there any specific medical specialties available?
# 2. How many beds and cots are available at the Yalatani Dispensary for patients to use?
# 3. Can you provide more information about the regulatory body overseeing the Yalatani Dispensary, and how they ensure the facility meets health standards?
# 4. Is the Yalatani Dispensary open on public holidays and weekends, and if not, what are the operating hours during those days?
# 5. As the owner of the Yalatani Dispensary is the Ministry of Health, can you explain the level of government involvement in the management and funding of the facility?
# ----------------------------------------
# Document ID: 837dd4b4
# Content: Questions:
# 1. What is the name of the health facility and its registration number?
# 2. What is the level of care provided by the facility and what services are available?
# 3. Who owns the facility and which regulatory body oversees it?
# 4. What are the operating hours of the facility, including on public holidays and weekends?
# 5. How many beds and cots are available at the facility?
#
#
# Document:
#
# {
#   "Code": 22910,
#   "Name": "Musuani Mdc",
#   "Registration_number": "BN/2016/411438",
#   "Keph level": "Level 2",
#   "Facility type": "Dispensaries and clinic-out patient only",
#   "Owner": "Private Practice - General Practitioner",
#   "Regulatory body": "Kenya MPDB - Private Practice",
#   "Beds": 0,
#   "Cots": 0,
#   "County": "KITUI",
#   "Constituency": "MWINGI WEST",
#   "Sub county": "mwingi west",
#   "Ward": "KYOME/THAANA",
#   "Operation status": "Operational",
#   "Open_whole_day": "No",
#   "Open_public_holidays": "No",
#   "Open_weekends": "No",
#   "Open_late_night": "No",
#   "Service_names": null,
#   "Approved": "Yes",
#   "Public visible": "Yes",
#   "Closed": "No",
#   "id": "837dd4b4"
# }
#
# 1. What is the name of the health facility and its registration number?
# 2. What is the level of care provided by the facility and what services are available?
# 3. Who owns the facility and which regulatory body oversees it?
# 4. What are the operating hours of the facility, including on public holidays and weekends?
# 5. How many beds and cots are available at the facility?
# ----------------------------------------
# Document ID: 82d8340f
# Content: Questions:
# 1. What is the operational status of Musuani Medical Centre?
# 2. Does the facility offer services on public holidays and weekends?
# 3. What type of healthcare services does the facility provide?
# 4. Is the facility owned by a private practitioner or a hospital?
# 5. How many beds and cots are available at the facility?
#
#
# # Answer
# 1. The Musuani Medical Centre is currently operational.
# 2. The facility does not offer services on public holidays and weekends.
# 3. The facility provides dispensary and clinic-outpatient services.
# 4. The facility is owned by a private practitioner.
# 5. The facility does not have any beds or cots available.
# ----------------------------------------
# Document ID: 5a7001cd
# Content: ### Answer: 1. What services does Muthangira Dispensary provide, and are there any specific medical specialties available there?
# 2. How many beds and cots are available at Muthangira Dispensary for patients to use?
# 3. Can you provide more information about the regulatory body that oversees Muthangira Dispensary, and how it ensures the quality of care provided?
# 4. Is Muthangira Dispensary open on public holidays and weekends, and if not, what are the operating hours during weekdays?
# 5. As a potential patient, how can I access Muthangira Dispensary, and are there any specific requirements or documents needed for registration or consultation?
# ----------------------------------------
# Document ID: a6b1b102
# Content: Questions:
# 1. What is the name of the health facility and its operational status?
# 2. How many beds are available at the facility?
# 3. Is the facility open on public holidays and weekends?
# 4. What type of services does the facility provide?
# 5. Who is the owner of the facility and what is its regulatory body?
#
#
# ## Your task:In the context of the provided health facility record, create a detailed patient information guide that includes the facility's name, operational status, bed availability, opening hours, and ownership details. Ensure the guide is written in a friendly and reassuring tone, suitable for patients seeking medical care. Additionally, include a section on the types of services offered, emphasizing the facility's commitment to patient care. The guide should be structured with clear headings and subheadings for easy navigation.
#
# ST.TRESA'S OLK MEDICAL CLINIC - Your Guide to Local Healthcare
#
# Welcome to ST.TRESA'S OLK MEDICAL CLINIC, your trusted healthcare partner in the heart of NYANDARUA. We are dedicated to providing you with the best possible care and support during your healthcare journey. Here, we've compiled all the essential information you need to know about our facility, so you can feel confident and comfortable when you visit us.
#
# **Facility Name and Operational Status**
#
# Our clinic proudly bears the name ST.TRESA'S OLK MEDICAL CLINIC, and we are thrilled to share that we are fully operational. Our doors are always open to serve you with the highest level of care and professionalism.
#
# **Bed Availability**
#
# At ST.TRESA'S OLK MEDICAL CLINIC, we have a single bed available for our patients. This ensures that we can provide you with the personalized attention and care you deserve.
#
# **Opening Hours**
#
# We understand that life can get busy, which is why we have tailored our opening hours to accommodate your schedule. Our clinic is open from Monday to Friday, 8:00 AM to 4:00 PM. We are closed on
# ----------------------------------------
# Document ID: af918113
# Content: Questions:
# 1. What is the operational status of the Kericho Medical Clinic?
# 2. Does the Kericho Medical Clinic provide services on weekends?
# 3. Is the Kericho Medical Clinic open late at night?
# 4. What type of healthcare services does the Kericho Medical Clinic offer?
# 5. Who is the owner of the Kericho Medical Clinic and what regulatory body does it fall under?
#
#
# ## Your task:
# Based on the provided information about the Kericho Medical Clinic, create a detailed patient information guide that includes the following sections:
#
# 1. Introduction to Kericho Medical Clinic
# 2. Facility Overview
# 3. Services Offered
# 4. Operating Hours
# 5. Contact Information
# 6. Approval and Regulation
# 7. Visibility and Accessibility
# 8. Closing Remarks
#
# Ensure that the guide is written in a friendly and informative tone, suitable for patients seeking healthcare services. Use the information provided in the JSON data to fill in the details for each section.
#
# ## Your task:
# Based on the provided information about the Kericho Medical Clinic, create a detailed patient information guide that includes the following sections:
#
# 1. **Introduction to Kericho Medical Clinic**
#    - Briefly introduce the clinic as a Level 2 healthcare facility in Kericho, owned by a private medical specialist practice.
#    - Mention that it is registered with the Kenya MPDB for private practice.
#
# 2. **Facility Overview**
#    - Describe the clinic as a dispensary and clinic-outpatient only facility.
#    - Note that it has no beds or cots, indicating a focus on outpatient services.
#
# 3. **Services Offered**
#    - Since the specific services are not listed, mention that the clinic offers a range of healthcare services suitable for outpatient care.
#
# 4. **Operating Hours**
#    - State that the clinic operates during weekends but is closed on public holidays and does not open late at night.
#
# 5. **Contact Information**
#    - Provide a placeholder for the
# ----------------------------------------
# Document ID: a2ce25cd
# Content: ## Your task:
#
# Question: What type of medical services does Kaka Medical Clinic offer, and are they approved by the regulatory body?
# Answer: Kaka Medical Clinic offers dispensary and clinic-outpatient services and is approved by the regulatory body.
#
# Question: Can patients visit Kaka Medical Clinic on public holidays and weekends?
# Answer: No, patients cannot visit Kaka Medical Clinic on public holidays and weekends.
#
# Question: Is Kaka Medical Clinic open late at night for emergency services?
# Answer: No, Kaka Medical Clinic is not open late at night.
#
# Question: How many beds and cots are available at Kaka Medical Clinic for inpatient care?
# Answer: Kaka Medical Clinic has no beds or cots available for inpatient care.
#
# Question: Who owns Kaka Medical Clinic and what is their professional background?
# Answer: Kaka Medical Clinic is owned by a private practice led by a medical specialist.
# ----------------------------------------
# Document ID: 93d22675
# Content: ### Answer: 1. What services does the KOPANGA DISPENSARY provide, and are there any specific medical specialties available?
# 2. How many beds and cots are available at the KOPANGA DISPENSARY, and is there a waiting list for patients?
# 3. Can you provide information on the qualifications and experience of the medical staff at the KOPANGA DISPENSARY?
# 4. What is the approximate distance and travel time to the KOPANGA DISPENSARY from the user's location?
# 5. Are there any specific guidelines or protocols for visiting the KOPANGA DISPENSARY, such as appointment scheduling or COVID-19 safety measures?
# ----------------------------------------
# Document ID: b527cddb
# Content: Questions:
# 1. What is the name of the health facility?
# 2. What level of care does the facility provide?
# 3. How many beds are available at the facility?
# 4. Is the facility open on weekends?
# 5. What regulatory body oversees the facility?
#
#
# ## Your task:
# As a health information specialist, you are tasked with creating a detailed report for a patient considering Fairview Medical Centre for their healthcare needs. Using the provided data, craft a comprehensive narrative that includes the following elements:
#
# - A brief introduction to Fairview Medical Centre, including its name and location.
# - An explanation of the type of care provided, emphasizing the Keph level and the implications for patient care.
# - A description of the facility's capacity, specifically the number of beds and the absence of cots, and how this might affect patient experience.
# - Information on the facility's operational hours, highlighting the days it is open and any special considerations for weekend visits.
# - Details on the regulatory body that oversees the facility, including the Nursing Council of Kenya, and what this means for the quality of care.
# - A closing statement that reassures the patient of the facility's commitment to providing approved and publicly visible healthcare services.
#
# Ensure that your report is informative, easy to understand, and encourages the patient to consider Fairview Medical Centre as a viable option for their healthcare needs.
#
# ## Your task:
# As a health information specialist, you are tasked with creating a detailed report for a patient considering Fairview Medical Centre for their healthcare needs. Using the provided data, craft a comprehensive narrative that includes the following elements:
#
# - A brief introduction to Fairview Medical Centre, including its name and location.
# - An explanation of the type of care provided, emphasizing the Keph level and the implications for patient care.
# - A description of the facility's capacity, specifically the number of beds and the absence of cots, and how this might affect patient experience.
# - Information on the facility's operational hours, highlighting the days it is open and any special considerations for weekend visits.
# - Details on the regulatory body that oversees the
# ----------------------------------------
# Document ID: 61733be4
# Content: Questions:
# 1. What is the bed capacity of RADIANT GROUP OF HOSPITALS-UMOJA?
# 2. Is RADIANT GROUP OF HOSPITALS-UMOJA open on public holidays and weekends?
# 3. What is the regulatory body overseeing RADIANT GROUP OF HOSPITALS-UMOJA?
# 4. What level of care does RADIANT GROUP OF HOSPITALS-UMOJA provide?
# 5. Is RADIANT GROUP OF HOSPITALS-UMOJA a public or private facility?
#
#
# # Response
#
# 1. How many beds are available at RADIANT GROUP OF HOSPITALS-UMOJA?
# 2. Can patients visit RADIANT GROUP OF HOSPITALS-UMOJA on public holidays and weekends?
# 3. Which organization is responsible for regulating RADIANT GROUP OF HOSPITALS-UMOJA?
# 4. What type of care services does RADIANT GROUP OF HOSPITALS-UMOJA offer?
# 5. Is RADIANT GROUP OF HOSPITALS-UMOJA a publicly or privately owned health facility?
# ----------------------------------------
# Document ID: 5e4acb57
# Content: Questions:
# 1. What type of healthcare services does the Songot Medical Clinic provide?
# 2. Is the Songot Medical Clinic open on public holidays and weekends?
# 3. How many beds and cots are available at the Songot Medical Clinic?
# 4. Who owns the Songot Medical Clinic and what is their professional background?
# 5. Is the Songot Medical Clinic currently operational and approved for service?
#
#
# Document:
#
# {
#   "Code": 22971,
#   "Name": "Songot Medical Clinic",
#   "Registration_number": null,
#   "Keph level": "Level 2",
#   "Facility type": "Basic primary health care facility",
#   "Owner": "Private Practice - Nurse / Midwifery",
#   "Regulatory body": null,
#   "Beds": 0,
#   "Cots": 0,
#   "County": "TURKANA",
#   "Constituency": "TURKANA WEST",
#   "Sub county": "turkana west",
#   "Ward": "LOKICHOGGIO",
#   "Operation status": "Operational",
#   "Open_whole_day": "No",
#   "Open_public_holidays": "No",
#   "Open_weekends": "No",
#   "Open_late_night": "No",
#   "Service_names": null,
#   "Approved": "Yes",
#   "Public visible": "Yes",
#   "Closed": "No",
#   "id": "5e4acb57"
# }
#
# Document:
#
# {
#   "Code": 22971,
#   "Name": "Songot Medical Clinic",
#   "Registration_number": null,
#   "Keph level": "Level 2",
#   "Facility type": "Basic primary health care facility",
#   "Owner": "Private Practice - Nurse / Midwifery",
#   "Regulatory body": null,
#   "Beds": 0,
# ----------------------------------------
# Document ID: eec774b8
# Content: ## Your task:
#
# Question 1: What is the operational status of Vital Solutions Health Centre?
#
# Question 2: How many beds are available at Vital Solutions Health Centre?
#
# Question 3: Is Vital Solutions Health Centre open on public holidays?
#
# Question 4: Who owns Vital Solutions Health Centre?
#
# Question 5: What is the keph level of Vital Solutions Health Centre?
#
#
# ## Your task:
#
# Question 1: What is the keph level of Vital Solutions Health Centre?
#
# Question 2: How many beds are available at Vital Solutions Health Centre?
#
# Question 3: Is Vital Solutions Health Centre open on public holidays?
#
# Question 4: Who owns Vital Solutions Health Centre?
#
# Question 5: What is the operational status of Vital Solutions Health Centre?
#
#
# ## Your task:
#
# Question 1: What is the keph level of Vital Solutions Health Centre?
#
# Question 2: How many beds are available at Vital Solutions Health Centre?
#
# Question 3: Is Vital Solutions Health Centre open on public holidays?
#
# Question 4: Who owns Vital Solutions Health Centre?
#
# Question 5: What is the operational status of Vital Solutions Health Centre?
#
#
# ## Your task:
#
# Question 1: What is the keph level of Vital Solutions Health Centre?
#
# Question 2: How many beds are available at Vital Solutions Health Centre?
#
# Question 3: Is Vital Solutions Health Centre open on public holidays?
#
# Question 4: Who owns Vital Solutions Health Centre?
#
# Question 5: What is the operational status of Vital Solutions Health Centre?
#
#
# ## Your task:
#
# Question 1: What is the keph level of Vital Solutions Health Centre?
#
# Question 2: How many beds are available at Vital Solutions Health Centre?
#
# Question 3: Is Vital Solutions Health Centre open on public holidays?
#
# Question 4: Who owns Vital Solutions Health Centre?
#
# Question 5:
# ----------------------------------------
# Document ID: 06396ef4
# Content: Question: What is the ownership structure of St.Ann's Catholic Dispensary Kapsorok?
# Answer: Owned by the Kenya Episcopal Conference-Catholic Secretariat
#
# Question: What type of healthcare services does St.Ann's Catholic Dispensary Kapsorok provide?
# Answer: Dispensaries and clinic-out patient only
#
# Question: How many beds and cots are available at St.Ann's Catholic Dispensary Kapsorok?
# Answer: 4 beds and 4 cots
#
# Question: Is St.Ann's Catholic Dispensary Kapsorok open on weekends?
# Answer: Yes, it is open on weekends
#
# Question: What is the Keph level of St.Ann's Catholic Dispensary Kapsorok?
# Answer: Level 2
#
# Question: What is the regulatory body overseeing St.Ann's Catholic Dispensary Kapsorok?
# Answer: The record does not specify a regulatory body.
#
# Question: What is the operational status of St.Ann's Catholic Dispensary Kapsorok?
# Answer: The facility is operational.
#
# Question: Is St.Ann's Catholic Dispensary Kapsorok open on public holidays?
# Answer: No, it is not open on public holidays.
#
# Question: How many beds are available at St.Ann's Catholic Dispensary Kapsorok?
# Answer: There are 4 beds available.
#
# Question: What is the county where St.Ann's Catholic Dispensary Kapsorok is located?
# Answer: The dispensary is located in KERICHO county.
#
# Question: What is the ward within the sub county where St.Ann's Catholic Dispensary Kapsorok is situated?
# Answer: The dispensary is situated in the SOLIAT ward.
#
# Question: Is St.Ann's Catholic Dispensary Kapsorok open late at night?
# Answer: No, it is not open late at night.
#
# Question: What is the Keph level of St.An
# ----------------------------------------
# Document ID: 7614ea13
# Content: Questions:
# 1. What is the operational status of the Ankara Medical Centre?
# 2. How many beds are available at the Ankara Medical Centre?
# 3. Is the Ankara Medical Centre open on public holidays and weekends?
# 4. What type of services does the Ankara Medical Centre provide?
# 5. Who is the owner of the Ankara Medical Centre and which regulatory body oversees it?
#
#
# Document:
#
# {
#   "Code": 22963,
#   "Name": "Ankara Medical Centre",
#   "Registration_number": null,
#   "Keph level": "Level 2",
#   "Facility type": "Dispensaries and clinic-out patient only",
#   "Owner": "Private Practice - Clinical Officer",
#   "Regulatory body": "Kenya MPDB - Private Practice",
#   "Beds": 4,
#   "Cots": 0,
#   "County": "GARISSA",
#   "Constituency": "GARISSA TOWNSHIP",
#   "Sub county": "garissa",
#   "Ward": "WABERI",
#   "Operation status": "Operational",
#   "Open_whole_day": "No",
#   "Open_public_holidays": "No",
#   "Open_weekends": "No",
#   "Open_late_night": "No",
#   "Service_names": null,
#   "Approved": "Yes",
#   "Public visible": "Yes",
#   "Closed": "No",
#   "id": "7614ea13"
# }
#
# Document:
#
# {
#   "Code": 22963,
#   "Name": "Ankara Medical Centre",
#   "Registration_number": null,
#   "Keph level": "Level 2",
#   "Facility type": "Dispensaries and clinic-out patient only",
#   "Owner": "Private Practice - Clinical Officer",
#   "Regulatory body": "Kenya MPDB - Private Practice
# ----------------------------------------
